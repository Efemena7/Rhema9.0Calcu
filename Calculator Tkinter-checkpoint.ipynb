# %%
from tkinter import *
from tkinter import ttk

def display_value(value):
    ent.insert(END,value)

def compute_value():
    result=eval(ent.get())
    ent.delete(0,END)
    ent.insert(END,result)

def clear_():
    ent.delete(0,END)
    
root=Tk()
root.title("A Simple Calculator")
root.config(bg="light blue")

name=Label(root,text="Calulator",bd=6)
name.grid(row=0,column=0,columnspan=3)

ent=Entry(root,relief=SUNKEN,bg="light pink")
ent.grid(column=1,row=1,columnspan=3,pady=5,ipadx=80)

plant=Frame(root,relief=RAISED,bd=6,bg="black")
plant.grid(row=2,column=1)

butt_1=ttk.Button(plant,text="7",command=lambda:display_value(7))
butt_1.grid(row=3,column=1)

butt_2=ttk.Button(plant,text="8",command=lambda:display_value(8))
butt_2.grid(row=3,column=2)

butt_3=ttk.Button(plant,text="9",command=lambda:display_value(9))
butt_3.grid(row=3,column=3)

butt_4=ttk.Button(plant,text="4",command=lambda:display_value(4))
butt_4.grid(row=4,column=1)

butt_5=ttk.Button(plant,text="5",command=lambda:display_value(5))
butt_5.grid(row=4,column=2)

butt_6=ttk.Button(plant,text="6",command=lambda:display_value(6))
butt_6.grid(row=4,column=3)

butt_7=ttk.Button(plant,text="1",command=lambda:display_value(1))
butt_7.grid(row=5,column=1)

butt_8=ttk.Button(plant,text="2",command=lambda:display_value(2))
butt_8.grid(row=5,column=2)

butt_9=ttk.Button(plant,text="3",command=lambda:display_value(3))
butt_9.grid(row=5,column=3)

butt_10=ttk.Button(plant,text="0",command=lambda:display_value(0))
butt_10.grid(row=6,column=1)

butt_=ttk.Button(plant,text="=",command=compute_value)
butt_.grid(row=6,column=2,columnspan=2,ipadx=38)

butt_a=ttk.Button(plant,text="+",command=lambda:display_value("+"))
butt_a.grid(column=1,row=2)

butt_s=ttk.Button(plant,text="-",command=lambda:display_value("-"))
butt_s.grid(row=2,column=2)

butt_d=ttk.Button(plant,text="/",command=lambda:display_value("/"))
butt_d.grid(row=2,column=3)

butt_m=ttk.Button(plant,text="*",command=lambda:display_value("*"))
butt_m.grid(row=2,column=4)

butt_c=ttk.Button(plant,text="clear",command=clear_)
butt_c.grid(row=3,column=4,rowspan=4,ipady=37)
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk

def display_value(value):
    bleach.insert(END,value)
    
def compute_value():
    result=eval(bleach.get())
    bleach.delete(0,END)
    bleach.insert(END,result)
    
anime=Tk(className=" CALCULATOR")

Label(anime,text="Calulator").grid(row=0,column=0,columnspan=3)

bleach=Entry(anime,bd=6,relief=SUNKEN)
bleach.grid(row=1,column=1,pady=4,ipady=1,ipadx=80)

naruto=Frame(anime,bd=6,relief=RAISED)
naruto.grid(row=2,column=1)

ttk.Button(naruto,text="1",command=lambda:display_value(1)).grid(row=2,column=1,pady=2,padx=3)

ttk.Button(naruto,text="2",command=lambda:display_value(2)).grid(row=2,column=2,pady=2,padx=3)

ttk.Button(naruto,text="3",command=lambda:display_value(3)).grid(row=2,column=3,pady=2,padx=3)

ttk.Button(naruto,text="4",command=lambda:display_value(4)).grid(row=2,column=4,pady=2,padx=3)

ttk.Button(naruto,text="5",command=lambda:display_value(5)).grid(row=3,column=1,pady=2,padx=3)

ttk.Button(naruto,text="6",command=lambda:display_value(6)).grid(row=3,column=2,pady=2,padx=3)

ttk.Button(naruto,text="7",command=lambda:display_value(7)).grid(row=3,column=3,pady=2,padx=3)

ttk.Button(naruto,text="8",command=lambda:display_value(8)).grid(row=3,column=4,pady=2,padx=3)

ttk.Button(naruto,text="9",command=lambda:display_value(9)).grid(row=4,column=1,pady=2,padx=3)

ttk.Button(naruto,text="0",command=lambda:display_value(0)).grid(row=4,column=2,pady=2,padx=3)

ttk.Button(naruto,text="+",command=lambda:display_value("+")).grid(row=4,column=3,pady=2,padx=3)

ttk.Button(naruto,text="-",command=lambda:display_value("-")).grid(row=4,column=4,pady=2,padx=3)

ttk.Button(naruto,text="*",command=lambda:display_value("*")).grid(row=5,column=1,pady=2,padx=3)

ttk.Button(naruto,text="/",command=lambda:display_value("/")).grid(row=5,column=2,pady=2,padx=3)

ttk.Button(naruto,text="=",command=compute_value).grid(row=5,column=3,columnspan=2,pady=2,padx=3,ipady=1,ipadx=41)
                             
anime.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Input In [57], in <cell line: 22>()
#      19 naruto=Frame(anime,bd=6,relief=RAISED)
#      20 naruto.grid(row=2,column=1)
# ---> 22 ttk.Button(naruto,text="1",command=lambda:display_value(1),bg="white").grid(row=2,column=1,pady=2,padx=3)
#      24 ttk.Button(naruto,text="2",command=lambda:display_value(2)).grid(row=2,column=2,pady=2,padx=3)
#      26 ttk.Button(naruto,text="3",command=lambda:display_value(3)).grid(row=2,column=3,pady=2,padx=3)
#
# File ~\anaconda3\lib\tkinter\ttk.py:607, in Button.__init__(self, master, **kw)
#     595 def __init__(self, master=None, **kw):
#     596     """Construct a Ttk Button widget with the parent master.
#     597
#     598     STANDARD OPTIONS
#    (...)
#     605         command, default, width
#     606     """
# --> 607     Widget.__init__(self, master, "ttk::button", kw)
#
# ...
